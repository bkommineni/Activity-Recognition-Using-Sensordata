# %%
# %matplotlib inline

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

# %%
frame = pd.read_csv("./../FeaturesCsvFile/featuresfile.csv")

# %%
scatter_matrix(frame)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13777c9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137715cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1377b4898>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ea24278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e15d898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d8959b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d007be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d69ee48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c096e80>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13804e390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13806e860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13809c4e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1380cb0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1380f0c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1380d2c50>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138b3a208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138b66668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138b9d588>],
#        ...,
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x14fb5dba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14fb90278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14fbca748>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150446588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x15047f588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1504b6a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1504c2780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150527128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150560128>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150dd0f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150e07f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150e4e4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x150e521d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150eb1a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150ee9a58>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x151763cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x15179ecf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1517d8c88>]], dtype=object)
